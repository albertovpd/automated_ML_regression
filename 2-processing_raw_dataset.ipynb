# %% [markdown]
# # Processing dataset before applying ML.
#
# I came from **Part I**, and thanks to that I have the dataset showed below. now it's time to process it before applying ML.
#
# - Part I. Gathering data: **https://github.com/albertovpd/automated_ML_regression/blob/master/1-creating_raw_dataset.ipynb**
#
# Process for what? Well, I'm going to move my target column 4 weeks ahead, so the rows of the dataset will be related with the rows of my target, 4 weeks in advance.
#
# Thanks to that, the last row of my dataset (today 2020.11.05) will infer my target column the day 2020.12.03.
#
# - Part III. ML: **https://github.com/albertovpd/automated_ML_regression/blob/master/3-ml_regression.ipynb**

# %%
import pandas as pd

# %%
dataset=pd.read_csv("input/dataset_final.csv")

# %% [markdown]
# - List of features I have to play with:

# %%
list(dataset.columns)
# Out:
# ['Unnamed: 0',
#  'date',
#  'protestas_x',
#  'extremismo_x',
#  'rebelion_x',
#  'refugiados_x',
#  'precio_petroleo_x',
#  'juicio_x',
#  'corrupcion_x',
#  'inestabilidad_politica_x',
#  'terrorismo_x',
#  'vigilancia_x',
#  'seguridad_nacional_x',
#  'ejercito_x',
#  'protestas_y',
#  'extremismo_y',
#  'rebelion_y',
#  'refugiados_y',
#  'precio_petroleo_y',
#  'juicio_y',
#  'corrupcion_y',
#  'inestabilidad_politica_y',
#  'terrorismo_y',
#  'vigilancia_y',
#  'seguridad_nacional_y',
#  'ejercito_y',
#  'stock_market',
#  'quiebra_economica',
#  'inflacion_economica',
#  'precio_petroleo',
#  'libre_comercio',
#  'job_quality_&_labor_market_performance',
#  'banco_mundial',
#  'finanzas_y_bancos',
#  'desempleo_x',
#  'prosperidad_economica_y_finanzas',
#  'incertidumbre_economica',
#  'crecimiento_economico',
#  'macroeconomia_deuda_y_vulnerabilidad',
#  'pobreza',
#  'ciencia',
#  'racismo',
#  'inmigracion_x',
#  'emergencia_sanitaria',
#  'vacunas',
#  'censura_en_medios',
#  'emprendimiento_x',
#  'energias_renovables',
#  'subsidios',
#  'agresion_sexual',
#  'precio_vivienda',
#  'enfermedades_muy_infecciosas',
#  'amazon',
#  'autonomo',
#  'ayuda alquiler',
#  'badi',
#  'banco alimentos',
#  'barometro',
#  'bildu',
#  'bullying',
#  'cabify',
#  'caritas',
#  'ciudadanos',
#  'clases online',
#  'comedor social',
#  'comparecencia',
#  'compartir piso',
#  'compromis',
#  'coronavirus',
#  'corrupcion',
#  'crisis economica',
#  'crisis política',
#  'cruz roja',
#  'cursos online',
#  'deliveroo',
#  'desempleo_y',
#  'desescalada',
#  'deshaucio',
#  'disney',
#  'divorcio',
#  'embarazo',
#  'emprendimiento_y',
#  'en casa',
#  'en familia',
#  'erc',
#  'erte',
#  'estado de alarma',
#  'examenes',
#  'formacion',
#  'glovo',
#  'hacer deporte',
#  'hangouts',
#  'hbo',
#  'hipoteca',
#  'idealista',
#  'independentismo',
#  'infeccion',
#  'inmigracion_y',
#  'just eat',
#  'manifestacion',
#  'mas pais',
#  'medico',
#  'meditacion',
#  'meetic',
#  'menu escolar',
#  'nacionalismo',
#  'negocio online',
#  'netflix',
#  'pandemia',
#  'paro',
#  'piso barato',
#  'pnv',
#  'podemos',
#  'pp',
#  'productividad',
#  'protesta',
#  'psoe',
#  'refugiados',
#  'remoto',
#  'residencia ancianos',
#  'sepe',
#  'skype',
#  'steam',
#  'taxi',
#  'teletrabajo',
#  'tinder',
#  'uber',
#  'uber eats',
#  'videoconferencia',
#  'videollamada',
#  'vox',
#  'yoga',
#  'zoom']

# %%
dataset.drop(columns='Unnamed: 0', inplace=True)
# Unemployment, which is how much people searches "desempleo" in Spain, will be my target to infere
dataset.rename(columns={'desempleo_y':"unemployment"}, inplace=True)

# %% [markdown]
# # Sliding time
#
# - I'm going to create a new dataset with *unemployment*, my target column and date
# - Remove *unemployment* from the old dataset
# - In the old dataset, add 4 weeks to the date rows. In this way, everythin happening right now will be linked with unemployment 4 weeks ahead
# - Merge the *unemployment* and date dataset with the old one with changed dates
#
# Summing up, change the dates 4 weeks ahead of everything but *unemployment* column

# %%
dataset["date"]=pd.to_datetime(dataset["date"])
df_unemployment=pd.DataFrame(dataset[["date", "unemployment"]])
dataset.drop(columns="unemployment", inplace=True)
dataset.head

# %%
from datetime import timedelta

# %%
dataset["date"]=dataset["date"].apply(lambda x: x+timedelta(weeks=4))
dataset.head()

# %%
# now let's merge again
df=pd.merge(dataset,df_unemployment,how='outer', on=["date"],suffixes=(None,None))
df.sort_values(by=["date"],inplace=True)
df=df.fillna(0)

# great, everything but "unemployment" has been moved 3 weeks ahead
df.head()

# %%
df.reset_index(drop=True,inplace=True)
# lets remove the first 3 rows, they are redundant
df.drop([0,1,2,3], inplace=True)

# %%
df.to_csv("input/dataset_final_processed.csv")
df
# Out:
#          date  protestas_x  extremismo_x  rebelion_x  refugiados_x  \
# 4  2019-02-03    -0.986667    -29.993333  -21.453333     -6.425000
# 5  2019-02-10   -16.754286     -2.260000  -17.413333    -15.266667
# 6  2019-02-17   -98.830000     -5.644000  -26.305000      0.000000
# 7  2019-02-24   -41.448571     -4.226667  -26.570000      1.276000
# 8  2019-03-03   -35.362857      0.000000  -28.106667    -20.310000
# ..        ...          ...           ...         ...           ...
# 93 2020-10-18    -7.955000     -4.300000   -4.933333     -3.205000
# 94 2020-10-25   -10.885714     -4.375000   -2.670000     -3.600000
# 95 2020-11-01   -15.368000     -3.420000    0.000000     -3.880000
# 96 2020-11-08    -6.241667      0.000000   -1.250000     -4.330000
# 97 2020-11-15    -8.295000      0.000000   -4.800000     -0.665000
#
#     precio_petroleo_x    juicio_x  corrupcion_x  inestabilidad_politica_x  \
# 4                0.00 -111.880000    -92.164000                 -7.770000
# 5                0.00 -485.394286   -168.828571                -23.500000
# 6                3.72 -232.251429   -106.468571                -36.120000
# 7                0.00 -233.122857   -106.342857                -24.146667
# 8                0.00 -173.451429   -112.497143                 -5.160000
# ..                ...         ...           ...                       ...
# 93               0.00  -44.481429    -53.120000                 -7.480000
# 94               0.00  -57.642857    -28.765714                  0.000000
# 95               0.00  -73.910000    -18.664286                -39.070000
# 96               0.00  -39.984286    -30.545714                -14.970000
# 97               0.00 -103.931667    -36.138571                 -3.990000
#
#     terrorismo_x  ...  teletrabajo  tinder   uber  uber eats  \
# 4     -82.140000  ...          2.0    56.0   27.0       10.0
# 5     -11.586667  ...          1.0    51.0   35.0       15.0
# 6    -145.260000  ...          2.0    50.0  100.0        9.0
# 7     -34.084000  ...          2.0    52.0   78.0       11.0
# 8     -24.512000  ...          1.0    50.0   40.0       11.0
# ..           ...  ...          ...     ...    ...        ...
# 93     -3.300000  ...        100.0    88.0   45.0       75.0
# 94     -7.586000  ...         43.0    88.0   48.0       90.0
# 95     -4.770000  ...         24.0    82.0   46.0       91.0
# 96     -3.846667  ...         38.0    90.0   47.0      100.0
# 97     -5.055000  ...         25.0    82.0   47.0       99.0
#
#     videoconferencia  videollamada   vox  yoga  zoom  unemployment
# 4                2.0           2.0  35.0  50.0   5.0          23.0
# 5                3.0           1.0  27.0  44.0   4.0          23.0
# 6                3.0           2.0  16.0  41.0   3.0          23.0
# 7                3.0           3.0  11.0  49.0   4.0          20.0
# 8                3.0           2.0  13.0  48.0   4.0          27.0
# ..               ...           ...   ...   ...   ...           ...
# 93              17.0           7.0   8.0  47.0  22.0          27.0
# 94              17.0           8.0  10.0  46.0  20.0           0.0
# 95              10.0           5.0   8.0  45.0  20.0           0.0
# 96               8.0           7.0  11.0  42.0  18.0           0.0
# 97              13.0           7.0  11.0  39.0  21.0           0.0
#
# [94 rows x 132 columns]

# %% [markdown]
# # All right! I have my dataset as I want. Now it's time for the feature engineering fun!
#
# - Find better features to work with "unemployment". Greedy algorithm.
# - Normalise and standarise the dataset.
# - Apply my personal weights, so every week closer to the actual date will be worth more than far weeks.
#
#
# - Part III: **https://github.com/albertovpd/automated_ML_regression/blob/master/3-ml_regression.ipynb**
